# %% [markdown]
# **IS362 Week12 - Scrape data from The New York Times**

# %%
#loading libraries
import urllib.request
import json
from pandas.io.json import json_normalize
import pandas as pd
import numpy as np
import sys
from pandas import DataFrame, read_csv

# %% [markdown]
# Looked at stackoverflow and i noticed that the urllib2 module has been split across several modules in Python 3 named urllib.request and urllib.error. The 2to3 tool will automatically adapt imports when converting your sources to Python 3.

# %%
api_key = '27fc6554b9e74f7d8b90581f293ff037'
url = 'https://api.nytimes.com/svc/mostpopular/v2/mostviewed/Opinion/30.json?limit=100'
string = url+'&api-key='+api_key

response = str(urllib.request.urlopen(string).read(), 'utf-8')

df = pd.read_json(response)
df
# Out:
#                                             copyright  num_results  \
# 0   Copyright (c) 2017 The New York Times Company....          254
# 1   Copyright (c) 2017 The New York Times Company....          254
# 2   Copyright (c) 2017 The New York Times Company....          254
# 3   Copyright (c) 2017 The New York Times Company....          254
# 4   Copyright (c) 2017 The New York Times Company....          254
# 5   Copyright (c) 2017 The New York Times Company....          254
# 6   Copyright (c) 2017 The New York Times Company....          254
# 7   Copyright (c) 2017 The New York Times Company....          254
# 8   Copyright (c) 2017 The New York Times Company....          254
# 9   Copyright (c) 2017 The New York Times Company....          254
# 10  Copyright (c) 2017 The New York Times Company....          254
# 11  Copyright (c) 2017 The New York Times Company....          254
# 12  Copyright (c) 2017 The New York Times Company....          254
# ...

# %%
data = json.loads(response)
popular = json_normalize(data['results'])
popular
# Out:
#                                              abstract  \
# 0   Dear President Trump: Are we going to lose so ...
# 1   We are now experiencing the very thing Team Tr...
# 2   Understanding how she got swept up in evil has...
# 3   We use them to try to “get to know” people. It...
# 4   What if the Trump administration runs out of e...
# 5         Sounds like investment, smells like ripoff.
# 6                   Welcome to Trump&#8217;s America.
# 7                   Chewing over the cultural divide.
# 8   Statistics don&#8217;t win elections. Does tha...
# 9                Everything is an insult, apparently.
# 10  People who have depended on programs that woul...
# 11  On college applications, every so often, the k...
# 12          The untruths about Russia are escalating.
# 13  New research indicates a stall, maybe even a r...
# 14  The president my fellow believers elected is a...
# 15  The defeated candidate, always careful as a po...
# ...

# %% [markdown]
# In conclusion i managed to get the results from the apikey i recieved the results so i could create a data frame from that. However, i also tried to run['doc's] with the Data frame and had no luck with that.
